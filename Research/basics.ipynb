# %% [markdown]
# # Basic Completion

# %%
AI21_API = 'MWoMUJbSC3GgrEKx51opEooZW1OGAdOL'

# %%
import ai21

# %%
ai21.api_key = AI21_API

# %%
prompt = "Last day I was in school"

# %%
response = ai21.Completion.execute(
    model='j2-large',
    prompt=prompt,
    temperature=0.65,
    minTokens=50,
    maxTokens=200,
    numResults=1
)

# %%
response
# Out:
# {'id': '69442909-a18f-19d3-bcc3-cf2ecb8c7479', 'prompt': {'text': 'Last day I was in school', 'tokens': [{'generatedToken': {'token': '▁Last', 'logprob': -7.82759952545166, 'raw_logprob': -7.82759952545166}, 'topTokens': None, 'textRange': {'start': 0, 'end': 4}}, {'generatedToken': {'token': '▁day', 'logprob': -4.873093605041504, 'raw_logprob': -4.873093605041504}, 'topTokens': None, 'textRange': {'start': 4, 'end': 8}}, {'generatedToken': {'token': '▁I▁was', 'logprob': -7.124204158782959, 'raw_logprob': -7.124204158782959}, 'topTokens': None, 'textRange': {'start': 8, 'end': 14}}, {'generatedToken': {'token': '▁in▁school', 'logprob': -7.493080139160156, 'raw_logprob': -7.493080139160156}, 'topTokens': None, 'textRange': {'start': 14, 'end': 24}}]}, 'completions': [{'data': {'text': '.\nI have 4+ years.\nBut some guys have 10+ years.\nBut in their eyes, they are not old.\nThey are young and fresh.\nSo, they are so naughty.\nAnd I am the student.\nAnd I am the naughty.\nThey laugh an
# ...

# %%
response.completions[0].data.text
# Out:
# '.\nI have 4+ years.\nBut some guys have 10+ years.\nBut in their eyes, they are not old.\nThey are young and fresh.\nSo, they are so naughty.\nAnd I am the student.\nAnd I am the naughty.\nThey laugh and smile at me.\nAnd I am just a student.\nI am naughty, and they are naughty.\nThey are young and fresh.\nI am the student, and they are the teacher.\nSo, I am naughty, and they are the teacher.\nOne day, they give me class.\nAnd I am naughty, and they are the teacher.\nThey scold me, and they call me naughty.\nAnd I am just a student.\nI am naughty, and they are naughty.\nThey call me naughty, and I am naughty.\nThey are teacher, and I am naughty.\nI am naughty, and they are naughty.\nSo, I am the teacher, and they are naughty.\nThey are naughty, and I am naughty.\nI am naughty, and they are naughty.\nI am naughty, and they are, naughty.\n오늘 학교를 다녀왔습니다.\n4+년을 가지고'

# %%
len(response.completions[0].data.text)
# Out:
# 998

# %%
response.completions
# Out:
# [{'data': {'text': ", I didn't even realized it's already the 5th of October!\nBut I had this holiday booked from 6th to 13th, so I didn't want to waste it.\nSo, Saturday and Sunday have been spent at my parents house, where my sister and I cooked a lot and baked a lot.\nYesterday, after we had lunch, we packed our bags and left for our holiday.\nWe went to a cottage in Vrouwenpolder, which was quite far, but so beautiful!\nThe cottage was build in the thirties, and we could really see the old style.\nIt has its own 'shop
Snow White's mother died when she was very young, and her father, the king, married again. However, the new queen was vain and cruel, and she was jealous of Snow White's beauty. Every day, the queen would ask her magic mirror who the fairest of them all was. And every day, the mirror replied that the queen was the most beautiful in the land. But when Snow White grew up, the mirror declared that she was the fairest of them all.

Enraged with jealousy, the queen ordered a huntsman to take Snow White into the forest and kill her. The huntsman, however, took pity on the princess and couldn't bring himself to do the deed. He left Snow White alone in the forest and told her to never come back.

Lost and afraid, Snow White wandered through the forest until she came upon a small cottage. She went inside and found that it was the home of seven dwarfs: Grumpy, Happy, Doc, Bashful, Sneezy, Sleepy, and Dopey. The dwarfs were surprised to see her but kindly took her in and promised to protect her.

Snow White helped the dwarfs with their chores, and they grew fond of her. However, the wicked queen discovered that Snow White was still alive and decided to take matters into her own hands. Disguised as an old woman, the queen went to the cottage and tricked Snow White into biting into a poisoned apple. The apple put Snow White into a deep sleep, and the queen left, believing that she was dead.

The dwarfs arrived too late to save Snow White and placed her in a glass coffin. They mourned her loss and kept watch over her, hoping that someday a prince would come to wake her.

One day, a handsome prince was passing through the forest and saw Snow White's glass coffin. He was struck by her beauty and leaned in to kiss her. '''

# %%
with open('snowwhite.txt', 'a') as f:
    f.write('It was amazing.')

with open('snowwhite.txt', 'r') as f:
    text = f.read()

text
# Out:
# "Once upon a time in a far-off kingdom, there was a beautiful princess named Snow White. She had skin as white as snow, lips as red as blood, and hair as black as ebony. Snow White's stepmother, the queen, was very jealous of her beauty and wanted to be the most beautiful in the land.\n\nOne day, the queen ordered a huntsman to take Snow White into the forest and kill her. But the huntsman couldn't do it, so he left Snow White alone in the forest. Lost and afraid, Snow White stumbled upon a small cottage and met seven friendly dwarfs named Grumpy, Happy, Doc, Bashful, Sneezy, Sleepy, and Dopey.\n\nThe dwarfs were happy to have Snow White in their home, and they all became friends. But the wicked queen found out that Snow White was still alive and came to the cottage disguised as an old woman. She tricked Snow White into eating a poisoned apple and Snow White fell into a deep sleep.\n\nThe dwarfs put Snow White in a glass coffin and kept watch over her, hoping that someone would come 
# ...

# %%
response = ai21.Completion.execute(
    model='j2-large',
    prompt=context,
    temperature=0.65,
    minTokens=50,
    maxTokens=100,
    numResults=1
)

# %%
response.completions[0].data.text
# Out:
# ". . .\n\nAnd that's when I woke up.\n\n— From Snow White and the Seven Dwarfs by Bill Peet\n\nSnow White and the Seven Dwarfs (1937) by Walt Disney Productions, Walt Disney Feature Animation, Walt Disney Pictures, Disney Enterprises, Inc., Walt Disney Animation Studios, Walt Disney Home Entertainment, and Walt Disney Animation Studios\n\n(This post is dedicated to my sons, who have given me so much joy and laughter these past sixteen years.)"
